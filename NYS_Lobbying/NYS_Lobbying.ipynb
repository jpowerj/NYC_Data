# %%
import pandas as pd
import numpy as np

# %%
lobby_df = pd.read_csv("Registered_Lobbyist_Disclosures.csv")
# Out:
# C:\Users\jj\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (30,32,36,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
lobby_df.head()
# Out:
#    Reporting Year Reporting Period                              Lobbyist Name  \
# 0            2018               JA  1199 SEIU UNITED HEALTHCARE WORKERS EAST
# 1            2018               JF  1199 SEIU UNITED HEALTHCARE WORKERS EAST
# 2            2018               MA  1199 SEIU UNITED HEALTHCARE WORKERS EAST
# 3            2018               MJ  1199 SEIU UNITED HEALTHCARE WORKERS EAST
# 4            2018               ND  1199 SEIU UNITED HEALTHCARE WORKERS EAST
#
#      Lobbyist Address 1 Lobbyist Address 2 Lobbyist City Lobbyist State  \
# 0  330 WEST 42ND STREET          7TH FLOOR      NEW YORK             NY
# 1  330 WEST 42ND STREET          7TH FLOOR      NEW YORK             NY
# 2  330 WEST 42ND STREET          7TH FLOOR      NEW YORK             NY
# 3  330 WEST 42ND STREET          7TH FLOOR      NEW YORK             NY
# 4  330 WEST 42ND STREET          7TH FLOOR      NEW YORK             NY
#
# ...

# %%
lobby_df.sample().iloc[0]
# Out:
# Reporting Year                                                               2017
# Reporting Period                                                               MJ
# Lobbyist Name                      MERCURY PUBLIC AFFAIRS, LLC (FKA MERCURY, IGR)
# Lobbyist Address 1                                            99 SPRING ST. APT 4
# Lobbyist Address 2                                                            NaN
# Lobbyist City                                                           SARATOGA
# Lobbyist State                                                                 NY
# Lobbyist Zip                                                                12866
# Lobbyist Phone                                                       518-810-2468
# Lobbying Type                                                                   N
# Government Level                                                                B
# ...
